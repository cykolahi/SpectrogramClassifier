# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import librosa.display
#import IPython.display as ipd
import soundfile as sf

#import data_parserv2
#import get_country_from_coordinates
#import construct_final_dataset
#import test_and_show_spectrogram
import official_data_loader 
import official_data_parser
import official_data_developer

import show_train_test_split

# %%
#takes a csv of audio paths and countries and creates a pkl file of audio paths, countries, and spectrogram tensors
# %run official_data_developer

# %%
#takes a pkl file of audio paths, countries, and spectrogram tensors and splits them into training, validation, and test sets
# %run official_data_loader

# %%
#
# %run test_and_show_spectrogram
# %run show_train_test_split

# %%
# This file parses through the FMA metadata and creates a dataframe with the audio paths 
# and the corresponding coordinates of the audio file

#%run data_parserv2
# Out:
# Python executable: /Users/cyruskolahi/anaconda3/envs/dlproject/bin/python
# Current working directory: /Users/cyruskolahi/Documents/DLprojvenv/DL project
# Utils path: /Users/cyruskolahi/Documents/DLprojvenv/DL project/utils.py

# %%
# This file uses the coordinates to get the country of the audio file and constructs
# a new csv of corresponding audio paths and countries
# I wouldn't recomend running this file, it took about an hour for me to run

#%run get_country_from_coordinates

# %%
# This file constructs a final pkl file of audio paths, countries (balanced), and spectrogram tensors
# and splits them into training and test sets

#%run construct_final_dataset

# %%
#dont run this cell

#data_parser = official_data_parser.AudioLocationParser()
#data_parser.get_coordinates_with_audio_paths()

# %%
#data_developer = official_data_developer.AudioDataDeveloper(data_path='/projects/dsci410_510/Kolahi_data_temp/audio_paths_with_countries.csv')
#data_developer.load_data()  # Load and preprocess the data first
#data_developer.balance_dataset()  # Balance if needed
#data_developer.create_expanded_dataset()  # Now create the expanded dataset
#data_developer.create_train_test_split()
#data_developer.save_dataset('/projects/dsci410_510/Kolahi_data_temp/expanded_dataset_v8.pkl', format='pkl')

#%run official_data_developer
# Out:
# len(self.df): 2673
# len(self.df['country'].unique()): 24
# country
# United States             10
# Éire / Ireland            10
# Argentina                 10
# Česko                     10
# Україна                   10
# Србија                    10
# Brasil                    10
# Italia                    10
# Portugal                  10
# Россия                    10
# Nederland                 10
# India                     10
# Danmark                   10
# Sverige                   10
# Australia                 10
# New Zealand / Aotearoa    10
# France                    10
# Deutschland               10
# México                    10
# Canada                    10
# España                    10
# United Kingdom            10
# 日本                        10
# Colombia                  10
# Name: count, dtype: int64
# len(self.df): 240
# len(self.df['country'].unique()): 24
# [src/libmpg123/layer3.c:INT123_do_layer3():1804] error: dequantization failed!
# ...

# %%
#data_loader = official_data_loader.AudioDataLoader(data_path='/projects/dsci410_510/Kolahi_data_temp/expanded_dataset_v8.pkl')
#%run official_data_loader

# %%
# %run show_train_test_split
